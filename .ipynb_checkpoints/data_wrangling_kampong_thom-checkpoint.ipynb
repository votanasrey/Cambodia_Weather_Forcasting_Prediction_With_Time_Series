# %%
# importing the required modules
import glob
# Import the neccessary modules for data manipulation and visual representation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
path='../Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kampong_thom'
file_list = glob.glob(path + "/*.xlsx")

excl_list = []

for file in file_list:
    excl_list.append(pd.read_excel(file))
excl_merged = pd.DataFrame()

for excl_file in excl_list:
    excl_merged = excl_merged.append(excl_file, ignore_index=True)

excl_merged
# Out:
#                                  CE SAIN Weather Station Unnamed: 1  \
# 0      Export timeframe: Data from 01-09-2021 to30-09...        NaN
# 1                                 Location: Kompong Thom        NaN
# 2                                                    NaN        NaN
# 3                                                  Line#       Date
# 4                                                      1   20/09/01
# ...                                                  ...        ...
# 29415                                                NaN   21/03/30
# 29416                                                NaN   21/03/30
# 29417                                                NaN   21/03/30
# 29418                                                NaN   21/03/30
# 29419                                                NaN   21/03/31
#
#       Unnamed: 2             Unnamed: 3              Unnamed: 4 Unnamed: 5  \
# ...

# %%
pd.set_option('display.max_columns', None)

data = excl_merged
data.head()
# Out:
#                              CE SAIN Weather Station Unnamed: 1 Unnamed: 2  \
# 0  Export timeframe: Data from 01-09-2021 to30-09...        NaN        NaN
# 1                             Location: Kompong Thom        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                              Line#       Date       Time
# 4                                                  1   20/09/01   00:00:00
#
#               Unnamed: 3              Unnamed: 4 Unnamed: 5  \
# 0                    NaN                     NaN        NaN
# 1                    NaN                     NaN        NaN
# 2                    NaN                     NaN        NaN
# 3  Water Content (m3/m3)  Solar Radiation (W/m2)  Rain (mm)
# 4                  0.019                       1          0
#
#               Unnamed: 6 Unnamed: 7        Unnamed: 8        Unnamed: 9  \
# 0                    NaN        NaN               NaN               NaN
# ...

# %%
#since there are some Unnecessary colums appear from merged sooo clean them out
columns = ['CE SAIN Weather Station', 'Export settings name']
data.drop(columns, inplace=True, axis=1)
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [12], in <cell line: 3>()
#       1 #since there are some Unnecessary colums appear from merged sooo clean them out
#       2 columns = ['CE SAIN Weather Station', 'Export settings name']
# ----> 3 data.drop(columns, inplace=True, axis=1)
#       4 data.head()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...
