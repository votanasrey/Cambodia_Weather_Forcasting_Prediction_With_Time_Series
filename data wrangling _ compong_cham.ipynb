# %% [markdown]
# <hr/>
# <h1><center>Data Collection && Wrangling - Phnom Penh</center></h1>
# <hr/>
#
# ***

# %% [markdown]
# # Import Packages
# ***

# %%
# importing the required modules
import glob
# Import the neccessary modules for data manipulation and visual representation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# # Read the Data
# ***

# %%
# specifying the path to csv files
# change ur directory here based on pwd

path = "C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets"

# excel files in the path
file_list = glob.glob(path + "/raw_layer/kompong_cham" + "/*.xlsx")
file_list
# Out:
# ['C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\APRIL-2021.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\APRIL-2022.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\AUGUST-2021.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\DECEMBER-2020.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\DECEMBER-2021.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\FEBRUAEY-2022.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\FEBRUARY-2021.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\JANUARY-2021.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\JANUARY-2022.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\JULY-2021.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\JUNE-2021.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\MARCH-2021.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\MARCH-2022.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\MAY-2021.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\NOVEMBER-2020.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\NOVEMBER-2021.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\OCTOBER-2020.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\OCTOBER-2021.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\SEPTEMBER-2020.xlsx',
#  'C:/Users/osssa/Desktop/Projects II/Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kompong_cham\\SEPTEMBER-2021.xlsx']

# %%
# list of excel files we want to merge.
# pd.read_excel(file_path) reads the excel
# data into pandas dataframe.
excl_list = []

for file in file_list:
    excl_list.append(pd.read_excel(file))

# %%
# create a new dataframe to store the
# merged excel file.

excl_merged = pd.DataFrame()

for excl_file in excl_list:
    # appends the data into the excl_merged
    # dataframe.
    excl_merged = excl_merged.append(excl_file, ignore_index=True)

# exports the dataframe into excel file with
# specified n
#excl_merged.to_excel('merge_files.xlsx', index=False)
excl_merged
# Out:
#                              CE SAIN Weather Station KPC Unnamed: 1  \
# 0      Export timeframe: Data from 01-04-2021 to 1-04...        NaN
# 1                                 Location: Kampong Cham        NaN
# 2                                                    NaN        NaN
# 3                                                  Line#       Date
# 4                                                      1   21/04/01
# ...                                                  ...        ...
# 56447                                               2877   21/07/30
# 56448                                               2878   21/07/30
# 56449                                               2879   21/07/30
# 56450                                               2880   21/07/30
# 56451                                               2881   21/07/31
#
#       Unnamed: 2             Unnamed: 3               Unnamed: 4 Unnamed: 5  \
# 0            NaN                    NaN                      NaN        NaN
# 1            NaN                    NaN                      NaN        NaN
# 2            NaN                    NaN                      NaN        NaN
# 3           Time  Water Content (m3/m3)  Solar Radiation (W//m2)  Rain (mm)
# 4       00:00:00                 0.7186                        1          0
# ...          ...                    ...                      ...        ...
# 56447   23:00:00                -0.1169                        1          0
# 56448   23:15:00                -0.1528                        1          0
# 56449   23:30:00                -0.1179                        1          0
# 56450   23:45:00                -0.1778                        1          0
# 56451   00:00:00                 -0.115                        1          0
#
#       Unnamed: 6        Unnamed: 7        Unnamed: 8               Unnamed: 9  \
# 0            NaN               NaN               NaN                      NaN
# 1            NaN               NaN               NaN                      NaN
# 2            NaN               NaN               NaN                      NaN
# 3         RH (%)  Wind Speed (m/s)  Gust Speed (m/s)  Wind Direction (Degree)
# 4           78.4                 3                 6                      201
# ...          ...               ...               ...                      ...
# 56447       95.9                 0               0.7                      111
# 56448       95.8               0.3               1.3                      122
# 56449       95.8                 0                 1                      128
# 56450       95.5               0.3               1.3                      128
# 56451       95.4                 1                 2                      131
#
#                   Unnamed: 10          Unnamed: 11  \
# 0                         NaN                  NaN
# 1                         NaN                  NaN
# 2                         NaN                  NaN
# 3      Temperature (Celcius )  Dew Point (Celcius)
# 4                        27.7                23.63
# ...                       ...                  ...
# 56447                   24.63                23.96
# 56448                   24.87                24.19
# 56449                   24.85                24.16
# 56450                   24.94                24.21
# 56451                   24.97                24.21
#
#       Export settings name: KPC Data
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 56447                            NaN
# 56448                            NaN
# 56449                            NaN
# 56450                            NaN
# 56451                            NaN
#
# [56452 rows x 13 columns]

# %%
pd.set_option('display.max_columns', None)

data = excl_merged
data.head()
# Out:
#                          CE SAIN Weather Station KPC Unnamed: 1 Unnamed: 2  \
# 0  Export timeframe: Data from 01-04-2021 to 1-04...        NaN        NaN
# 1                             Location: Kampong Cham        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                              Line#       Date       Time
# 4                                                  1   21/04/01   00:00:00
#
#               Unnamed: 3               Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                    NaN                      NaN        NaN        NaN
# 1                    NaN                      NaN        NaN        NaN
# 2                    NaN                      NaN        NaN        NaN
# 3  Water Content (m3/m3)  Solar Radiation (W//m2)  Rain (mm)     RH (%)
# 4                 0.7186                        1          0       78.4
#
#          Unnamed: 7        Unnamed: 8               Unnamed: 9  \
# 0               NaN               NaN                      NaN
# 1               NaN               NaN                      NaN
# 2               NaN               NaN                      NaN
# 3  Wind Speed (m/s)  Gust Speed (m/s)  Wind Direction (Degree)
# 4                 3                 6                      201
#
#               Unnamed: 10          Unnamed: 11 Export settings name: KPC Data
# 0                     NaN                  NaN                            NaN
# 1                     NaN                  NaN                            NaN
# 2                     NaN                  NaN                            NaN
# 3  Temperature (Celcius )  Dew Point (Celcius)                            NaN
# 4                    27.7                23.63                            NaN

# %%
#since there are some Unnecessary colums appear from merged sooo clean them out
columns = ['CE SAIN Weather Station', 'CE SAIN Weather Station RUA']
data.drop(columns, inplace=True, axis=1)
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4648/3221787289.py in <module>
#       1 #since there are some Unnecessary colums appear from merged sooo clean them out
#       2 columns = ['CE SAIN Weather Station', 'CE SAIN Weather Station RUA']
# ----> 3 data.drop(columns, inplace=True, axis=1)
#       4 data.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['CE SAIN Weather Station' 'CE SAIN Weather Station RUA'] not found in axis"

# %%
# Rename Columns
# Renaming certain columns for better readability
data.rename(
    columns={'Unnamed: 1': 'date', 
                        'Unnamed: 2': 'time',
                        'Unnamed: 3': 'water_content',
                        'Unnamed: 4': 'solar_radiation',
                        'Unnamed: 5': 'rain',
                        'Unnamed: 6': 'temperature',
                        'Unnamed: 7': 'rh',
                        'Unnamed: 8' : 'wind_speed',
                        'Unnamed: 9' : 'gust_speed',
                        'Unnamed: 10' : 'wind_direction',
                        'Unnamed: 11' : 'dew_point',
}, inplace=True)

# %%
#moreover, I can see the number of rows which has the name of features 
data.drop(data[data.date == 'Date'].index, inplace=True)
data[data['date'] == 'date']
# Out:
# Empty DataFrame
# Columns: [CE SAIN Weather Station KPC, date, time, water_content, solar_radiation, rain, temperature, rh, wind_speed, gust_speed, wind_direction, dew_point, Export settings name: KPC Data]
# Index: []

# %%
#since there are some Unnecessary rows and null appear from merged sooo clean them out
data.dropna(subset=['date'], how='all', inplace=True)

# %%
#check the data is null or not
data.isnull().any()
# Out:
# CE SAIN Weather Station KPC        True
# date                              False
# time                              False
# water_content                     False
# solar_radiation                   False
# rain                              False
# temperature                       False
# rh                                False
# wind_speed                        False
# gust_speed                        False
# wind_direction                    False
# dew_point                         False
# Export settings name: KPC Data     True
# dtype: bool

# %%
#check the data is null or not
data.isnull().sum()
# Out:
# CE SAIN Weather Station KPC       11332
# date                                  0
# time                                  0
# water_content                         0
# solar_radiation                       0
# rain                                  0
# temperature                           0
# rh                                    0
# wind_speed                            0
# gust_speed                            0
# wind_direction                        0
# dew_point                             0
# Export settings name: KPC Data    45040
# dtype: int64

# %%
#save the dataset 
data.to_csv(path + "/intermediate_layer/kompong_cham/cleaned_dataset_kompong_cham.csv")
