# %%
# importing the required modules
import glob
# Import the neccessary modules for data manipulation and visual representation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
path='../Cambodia_Weather_Forcasting_Prediction_With_Time_Series/datasets/raw_layer/kampong_thom'
file_list = glob.glob(path + "/*.xlsx")

excl_list = []

for file in file_list:
    excl_list.append(pd.read_excel(file))
excl_merged = pd.DataFrame()

for excl_file in excl_list:
    excl_merged = excl_merged.append(excl_file, ignore_index=True)

excl_merged
# Out:
#                                  CE SAIN Weather Station Unnamed: 1  \
# 0      Export timeframe: Data from 01-09-2021 to30-09...        NaN
# 1                                 Location: Kompong Thom        NaN
# 2                                                    NaN        NaN
# 3                                                  Line#       Date
# 4                                                      1   20/09/01
# ...                                                  ...        ...
# 29415                                                NaN   21/03/30
# 29416                                                NaN   21/03/30
# 29417                                                NaN   21/03/30
# 29418                                                NaN   21/03/30
# 29419                                                NaN   21/03/31
#
#       Unnamed: 2             Unnamed: 3              Unnamed: 4 Unnamed: 5  \
# 0            NaN                    NaN                     NaN        NaN
# 1            NaN                    NaN                     NaN        NaN
# 2            NaN                    NaN                     NaN        NaN
# 3           Time  Water Content (m3/m3)  Solar Radiation (W/m2)  Rain (mm)
# 4       00:00:00                  0.019                       1          0
# ...          ...                    ...                     ...        ...
# 29415   23:00:00                -0.4737                       1          0
# 29416   23:15:00                -0.4737                       1          0
# 29417   23:30:00                -0.4737                       1          0
# 29418   23:45:00                -0.4737                       1          0
# 29419   00:00:00                -0.4737                       1          0
#
#                   Unnamed: 6 Unnamed: 7        Unnamed: 8        Unnamed: 9  \
# 0                        NaN        NaN               NaN               NaN
# 1                        NaN        NaN               NaN               NaN
# 2                        NaN        NaN               NaN               NaN
# 3      Temperature (Celcius)     RH (%)  Wind Speed (m/s)  Gust Speed (m/s)
# 4                      27.16       96.5                 0                 0
# ...                      ...        ...               ...               ...
# 29415                 -97.48          0                 1               2.3
# 29416                 -97.48          0               0.3               1.3
# 29417                 -97.48          0                 0               0.7
# 29418                 -97.48          0               0.3                 1
# 29419                 -97.48          0                 0               0.7
#
#                    Unnamed: 10          Unnamed: 11 Export settings name: KPT  \
# 0                          NaN                  NaN                       NaN
# 1                          NaN                  NaN                       NaN
# 2                          NaN                  NaN                       NaN
# 3      Wind Direction (Degree)  Dew Point (Celcius)                       NaN
# 4                          139                26.59                       NaN
# ...                        ...                  ...                       ...
# 29415                      192                 -273                      2877
# 29416                      194                 -273                      2878
# 29417                      201                 -273                      2879
# 29418                      201                 -273                      2880
# 29419                      202                 -273                      2881
#
#        Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 29415          NaN          NaN          NaN          NaN          NaN
# 29416          NaN          NaN          NaN          NaN          NaN
# 29417          NaN          NaN          NaN          NaN          NaN
# 29418          NaN          NaN          NaN          NaN          NaN
# 29419          NaN          NaN          NaN          NaN          NaN
#
# [29420 rows x 18 columns]

# %%
pd.set_option('display.max_columns', None)

data = excl_merged
data.head()
# Out:
#                              CE SAIN Weather Station Unnamed: 1 Unnamed: 2  \
# 0  Export timeframe: Data from 01-09-2021 to30-09...        NaN        NaN
# 1                             Location: Kompong Thom        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                              Line#       Date       Time
# 4                                                  1   20/09/01   00:00:00
#
#               Unnamed: 3              Unnamed: 4 Unnamed: 5  \
# 0                    NaN                     NaN        NaN
# 1                    NaN                     NaN        NaN
# 2                    NaN                     NaN        NaN
# 3  Water Content (m3/m3)  Solar Radiation (W/m2)  Rain (mm)
# 4                  0.019                       1          0
#
#               Unnamed: 6 Unnamed: 7        Unnamed: 8        Unnamed: 9  \
# 0                    NaN        NaN               NaN               NaN
# 1                    NaN        NaN               NaN               NaN
# 2                    NaN        NaN               NaN               NaN
# 3  Temperature (Celcius)     RH (%)  Wind Speed (m/s)  Gust Speed (m/s)
# 4                  27.16       96.5                 0                 0
#
#                Unnamed: 10          Unnamed: 11 Export settings name: KPT  \
# 0                      NaN                  NaN                       NaN
# 1                      NaN                  NaN                       NaN
# 2                      NaN                  NaN                       NaN
# 3  Wind Direction (Degree)  Dew Point (Celcius)                       NaN
# 4                      139                26.59                       NaN
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN

# %%
#since there are some Unnecessary colums appear from merged sooo clean them out
columns = ['Export settings name: KPT']
data.drop(columns, inplace=True, axis=1)
data.head()
# Out:
#                              CE SAIN Weather Station Unnamed: 1 Unnamed: 2  \
# 0  Export timeframe: Data from 01-09-2021 to30-09...        NaN        NaN
# 1                             Location: Kompong Thom        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                              Line#       Date       Time
# 4                                                  1   20/09/01   00:00:00
#
#               Unnamed: 3              Unnamed: 4 Unnamed: 5  \
# 0                    NaN                     NaN        NaN
# 1                    NaN                     NaN        NaN
# 2                    NaN                     NaN        NaN
# 3  Water Content (m3/m3)  Solar Radiation (W/m2)  Rain (mm)
# 4                  0.019                       1          0
#
#               Unnamed: 6 Unnamed: 7        Unnamed: 8        Unnamed: 9  \
# 0                    NaN        NaN               NaN               NaN
# 1                    NaN        NaN               NaN               NaN
# 2                    NaN        NaN               NaN               NaN
# 3  Temperature (Celcius)     RH (%)  Wind Speed (m/s)  Gust Speed (m/s)
# 4                  27.16       96.5                 0                 0
#
#                Unnamed: 10          Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0                      NaN                  NaN          NaN          NaN
# 1                      NaN                  NaN          NaN          NaN
# 2                      NaN                  NaN          NaN          NaN
# 3  Wind Direction (Degree)  Dew Point (Celcius)          NaN          NaN
# 4                      139                26.59          NaN          NaN
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %%
#since there are some Unnecessary colums appear from merged sooo clean them out
columns = ['CE SAIN Weather Station']
data.drop(columns, inplace=True, axis=1)
data.head()
# Out:
#   Unnamed: 1 Unnamed: 2             Unnamed: 3              Unnamed: 4  \
# 0        NaN        NaN                    NaN                     NaN
# 1        NaN        NaN                    NaN                     NaN
# 2        NaN        NaN                    NaN                     NaN
# 3       Date       Time  Water Content (m3/m3)  Solar Radiation (W/m2)
# 4   20/09/01   00:00:00                  0.019                       1
#
#   Unnamed: 5             Unnamed: 6 Unnamed: 7        Unnamed: 8  \
# 0        NaN                    NaN        NaN               NaN
# 1        NaN                    NaN        NaN               NaN
# 2        NaN                    NaN        NaN               NaN
# 3  Rain (mm)  Temperature (Celcius)     RH (%)  Wind Speed (m/s)
# 4          0                  27.16       96.5                 0
#
#          Unnamed: 9              Unnamed: 10          Unnamed: 11  \
# 0               NaN                      NaN                  NaN
# 1               NaN                      NaN                  NaN
# 2               NaN                      NaN                  NaN
# 3  Gust Speed (m/s)  Wind Direction (Degree)  Dew Point (Celcius)
# 4                 0                      139                26.59
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN

# %%
# Rename Columns
# Renaming certain columns for better readability
data.rename(
    columns={'Unnamed: 1': 'date', 
                        'Unnamed: 2': 'time',
                        'Unnamed: 3': 'water_content',
                        'Unnamed: 4': 'solar_radiation',
                        'Unnamed: 5': 'rain',
                        'Unnamed: 6': 'temperature',
                        'Unnamed: 7': 'rh',
                        'Unnamed: 8' : 'wind_speed',
                        'Unnamed: 9' : 'gust_speed',
                        'Unnamed: 10' : 'wind_direction',
                        'Unnamed: 11' : 'dew_point',
}, inplace=True)

# %%
#moreover, I can see the number of rows which has the name of features 
data.drop(data[data.date == 'Date'].index, inplace=True)
data[data['date'] == 'date']
# Out:
# Empty DataFrame
# Columns: [date, time, water_content, solar_radiation, rain, temperature, rh, wind_speed, gust_speed, wind_direction, dew_point, Unnamed: 12, Unnamed: 13, Unnamed: 14, Unnamed: 15, Unnamed: 16]
# Index: []

# %%
#since there are some Unnecessary rows and null appear from merged sooo clean them out
data.dropna(subset=['date'], how='all', inplace=True)

# %%
#check the data is null or not
data.isnull().any()
# Out:
# date               False
# time               False
# water_content       True
# solar_radiation     True
# rain               False
# temperature         True
# rh                 False
# wind_speed         False
# gust_speed         False
# wind_direction      True
# dew_point           True
# Unnamed: 12         True
# Unnamed: 13         True
# Unnamed: 14         True
# Unnamed: 15         True
# Unnamed: 16         True
# dtype: bool

# %%
#check the data is null or not
data.isnull().sum()
# Out:
# date                   0
# time                   0
# water_content        202
# solar_radiation      202
# rain                   0
# temperature          202
# rh                     0
# wind_speed             0
# gust_speed             0
# wind_direction       202
# dew_point            202
# Unnamed: 12        29170
# Unnamed: 13        29170
# Unnamed: 14        29170
# Unnamed: 15        29170
# Unnamed: 16        29170
# dtype: int64

# %%
#save the dataset 
data.to_csv("cleaned_dataset_kampong_thom.csv")
